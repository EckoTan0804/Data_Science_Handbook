# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# ## Basics

# %% [markdown]
# For all Matplotlib plots, we start by creating a figure and an axes.

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# In Matplotlib, the *figure* (an instance of the class `plt.Figure`) can be thought of as **a single container that contains all the objects representing axes, graphics, text, and labels.**
#
# The *axes* (an instance of the class `plt.Axes`) is what we see above: a bounding box with ticks and labels, which will eventually contain the plot elements that make up our visualization.
#
# Once we have created an axes, we can use the `ax.plot` function to plot some data.

# %%
# Object-oriented (OO) style

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
y = np.sin(x)
ax.plot(x, y);

# %% [markdown]
# Alternatively, we can use the pylab interface and let the figure and axes be created for us in the background

# %%
# MATLAB style
plt.plot(x, np.sin(x));

# %% [markdown]
# If we want to create a single figure with multiple lines, we can simply call the plot function multiple times:

# %%
# Object-oriented (OO) style

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))
ax.plot(x, np.cos(x), '--')

# %%
# MATLAB style

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# ## Adjusting the plot

# %% [markdown]
# ### Line colors and styles

# %% [markdown]
# #### Line colors
#
# To adjust the color, you can use the `color` keyword, which accepts a string argument representing virtually any imaginable color.
#
# The color can be specified in a variety of ways:

# %%
plt.plot(x, np.sin(x - 0), color='blue', label='Color name') # specify color by name
plt.plot(x, np.sin(x - 1), color='g', label='Color code') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75', label='Grayscale') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44', label='Hex code') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3), label='RGB value') # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse', label='HTML color name'); # all HTML color names supported
plt.ylim(-1, 5)
plt.legend()

# %% [markdown]
# If no color is specified, Matplotlib will automatically cycle through a set of default colors for multiple lines.

# %% [markdown]
# #### Line styles
#
# Adjust line style using the `linestyle` keyword.

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# %%
# Use the following codes for short
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# `linestyle` and `color` codes can be combined into a single non-keyword argument to the `plt.plot()` function:

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r'); # dotted red

# %% [markdown]
# These single-character color codes reflect the standard abbreviations in the RGB (Red/Green/Blue) and CMYK (Cyan/Magenta/Yellow/blacK) color systems, commonly used for digital color graphics.

# %% [markdown]
# ### Axes Limits
#
# The most basic way to adjust axis limits is to use the `plt.xlim()` and `plt.ylim()` methods:

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# A useful related method is `plt.axis()`, which allows you to set the `x` and `y` limits with a single call, by passing a list which specifies `[xmin, xmax, ymin, ymax]`:

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]) # [x_min, x_max, y_min, y_max]
# Out:
# [-1, 11, -1.5, 1.5]

# %% [markdown]
# `plt.axis()` can also (e.g.)
#
# - automatically tighten the bounds around the current plot

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');
# Out:
# (-0.5, 10.5, -1.0999971452300779, 1.099999549246729)

# %% [markdown]
# - Ensure an equal aspect ratio so that on your screen, one unit in `x` is equal to one unit in `y`

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %% [markdown]
# More capabilities of `plt.axis` refer to its docstring.

# %% [markdown]
# ## Labeling Plots

# %% [markdown]
# ### Titles and axis
#
# There're methods that can be used to quickly set titles and axis. The position, size, and style of these labels can be adjusted using optional arguments to the function (See docstrings of each method).

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# ### Plot legend
#
# Use `plt.legend()` to quickly create a legend.
#
# The easiest way to specify the label of each line using the label keyword of the plot function:

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# ## Aside: Matplotlib Gotchas
#
# While most `plt` functions translate directly to `ax` methods (such as `plt.plot()` → `ax.plot()`, `plt.legend()` → `ax.legend()`, etc.), this is not the case for all commands.
#
# In particular, functions to set limits, labels, and titles are slightly modified. For **transitioning between MATLAB-style functions and object-oriented methods**, make the following changes:
#
# - `plt.xlabel()` → `ax.set_xlabel()`
# - `plt.ylabel()` → `ax.set_ylabel()`
# - `plt.xlim()` → `ax.set_xlim()`
# - `plt.ylim()` → `ax.set_ylim()`
# - `plt.title()` → `ax.set_title()`

# %% [markdown]
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the `ax.set()` method to set all these properties at once:

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2), 
       xlabel='$x$', ylabel='$\sin(x)$', title='Simple Plot')
# Out:
# [(-2, 2),
#  Text(0, 0.5, '$\\sin(x)$'),
#  (0, 10),
#  Text(0.5, 0, '$x$'),
#  Text(0.5, 1.0, 'Simple Plot')]
